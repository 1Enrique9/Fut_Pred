# %% [markdown]
# # Equipos

# %%
import os
import pandas as pd

base_root = r"D:\Fut_Pred\Data_equipos\2024-2025"


def clean_col(col):
    parts = [str(c).strip() for c in col if str(c) != 'nan']
    parts = [p for p in parts if not p.startswith('Unnamed')]
    return '_'.join(parts) if parts else 'Unknown'

def detect_header_levels(path):
    preview = pd.read_excel(path, nrows=3, header=None)
    empty_counts = preview.isna().sum().tolist()
    if sum(empty_counts) > len(preview.columns):  
        return [0,1,2]
    else:
        return [0,1]

for league_folder in os.listdir(base_root):
    league_path = os.path.join(base_root, league_folder)
    
    if os.path.isdir(league_path):
        print(f"\n🏟️ Procesando liga: {league_folder}")
        
        # Recorre todos los Excel dentro de la liga
        for filename in os.listdir(league_path):
            if filename.endswith(".xlsx"):
                input_path = os.path.join(league_path, filename)
                output_path = os.path.join(league_path, filename.replace(".xlsx", "_flat.csv"))

                try:
                    headers = detect_header_levels(input_path)
                    df = pd.read_excel(input_path, header=headers)
                    df.columns = [clean_col(col) for col in df.columns.values]
                    df.to_csv(output_path, index=False, encoding='utf-8-sig')

                    print(f"  ✅ {filename} convertido correctamente → {os.path.basename(output_path)}")
                except Exception as e:
                    print(f"  ⚠️ Error procesando {filename}: {e}")
# Out:
# 🏟️ Procesando liga: Alemania
#   ✅ Augsburg.xlsx convertido correctamente → Augsburg_flat.csv
#   ✅ Bayern_Munich.xlsx convertido correctamente → Bayern_Munich_flat.csv
#   ✅ Bochum.xlsx convertido correctamente → Bochum_flat.csv
#   ✅ Dortmound.xlsx convertido correctamente → Dortmound_flat.csv
#   ✅ Eint Frankfurt.xlsx convertido correctamente → Eint Frankfurt_flat.csv
#   ✅ Freiburg.xlsx convertido correctamente → Freiburg_flat.csv
#   ✅ Gladbach.xlsx convertido correctamente → Gladbach_flat.csv
#   ✅ Heidenheim.xlsx convertido correctamente → Heidenheim_flat.csv
#   ✅ Hoffenheim.xlsx convertido correctamente → Hoffenheim_flat.csv
#   ✅ Holstein_Kiel.xlsx convertido correctamente → Holstein_Kiel_flat.csv
#   ✅ Leverkusen.xlsx convertido correctamente → Leverkusen_flat.csv
#   ✅ Mainz_05.xlsx convertido correctamente → Mainz_05_flat.csv
#   ✅ RB_Leipzig.xlsx convertido correctamente → RB_Leipzig_flat.csv
#   ✅ St. Pauli.xlsx convertido correctamente → St. Pauli_flat.csv
#   ✅ Stuttgart.xlsx convertido correctamente → Stuttgart_flat.csv
#   ✅ Union_Berlin.xlsx convertido correctamente → Union_Berlin_flat.csv
#   ✅ Werder_Bremen.xlsx convertido correctamente → Werder_Bremen_flat.csv
#   ✅ Wolfsburg.xlsx convertido correctamente → Wolfsburg_flat.csv
#
# 🏟️ Procesando liga: Francia
#   ✅ Angers.xlsx convertido correctamente → Angers_flat.csv
#   ✅ Auxerre.xlsx convertido correctamente → Auxerre_flat.csv
#   ✅ Brest.xlsx convertido correctamente → Brest_flat.csv
#   ✅ Lens.xlsx convertido correctamente → Lens_flat.csv
#   ✅ Le_Havre.xlsx convertido correctamente → Le_Havre_flat.csv
#   ✅ Lille.xlsx convertido correctamente → Lille_flat.csv
#   ✅ Lyon.xlsx convertido correctamente → Lyon_flat.csv
#   ✅ Marseille.xlsx convertido correctamente → Marseille_flat.csv
#   ✅ Monaco.xlsx convertido correctamente → Monaco_flat.csv
#   ✅ Montpellier.xlsx convertido correctamente → Montpellier_flat.csv
#   ✅ Nantes.xlsx convertido correctamente → Nantes_flat.csv
#   ✅ Nice.xlsx convertido correctamente → Nice_flat.csv
#   ✅ PSG.xlsx convertido correctamente → PSG_flat.csv
#   ✅ Reims.xlsx convertido correctamente → Reims_flat.csv
#   ✅ Rennes.xlsx convertido correctamente → Rennes_flat.csv
#   ✅ Saint-Étienne.xlsx convertido correctamente → Saint-Étienne_flat.csv
#   ✅ Strasbourg.xlsx convertido correctamente → Strasbourg_flat.csv
#   ✅ Toulouse.xlsx convertido correctamente → Toulouse_flat.csv
#
# 🏟️ Procesando liga: Inglaterra
#   ✅ Arsenal.xlsx convertido correctamente → Arsenal_flat.csv
#   ✅ Aston_Villa.xlsx convertido correctamente → Aston_Villa_flat.csv
#   ✅ Bournemouth.xlsx convertido correctamente → Bournemouth_flat.csv
#   ✅ Brentford.xlsx convertido correctamente → Brentford_flat.csv
#   ✅ Brighton.xlsx convertido correctamente → Brighton_flat.csv
#   ✅ Chelsea.xlsx convertido correctamente → Chelsea_flat.csv
#   ✅ Crystal_Palace.xlsx convertido correctamente → Crystal_Palace_flat.csv
#   ✅ Everton.xlsx convertido correctamente → Everton_flat.csv
#   ✅ Fulham.xlsx convertido correctamente → Fulham_flat.csv
#   ✅ Ipswich_Town.xlsx convertido correctamente → Ipswich_Town_flat.csv
#   ✅ Leicester.xlsx convertido correctamente → Leicester_flat.csv
#   ✅ Liverpool.xlsx convertido correctamente → Liverpool_flat.csv
#   ✅ Manchester_city.xlsx convertido correctamente → Manchester_city_flat.csv
#   ✅ Manchester_united.xlsx convertido correctamente → Manchester_united_flat.csv
#   ✅ Newcastle.xlsx convertido correctamente → Newcastle_flat.csv
#   ✅ Nothingham_Forest.xlsx convertido correctamente → Nothingham_Forest_flat.csv
#   ✅ Southampton.xlsx convertido correctamente → Southampton_flat.csv
#   ✅ Tottenham.xlsx convertido correctamente → Tottenham_flat.csv
#   ✅ West_Ham.xlsx convertido correctamente → West_Ham_flat.csv
#   ✅ Wolves.xlsx convertido correctamente → Wolves_flat.csv
#
# 🏟️ Procesando liga: Italia
#   ✅ Atalanta.xlsx convertido correctamente → Atalanta_flat.csv
#   ✅ Bologna.xlsx convertido correctamente → Bologna_flat.csv
#   ✅ Cagliari.xlsx convertido correctamente → Cagliari_flat.csv
#   ✅ Como.xlsx convertido correctamente → Como_flat.csv
#   ✅ Empoli.xlsx convertido correctamente → Empoli_flat.csv
#   ✅ Fiorentina.xlsx convertido correctamente → Fiorentina_flat.csv
#   ✅ Genoa.xlsx convertido correctamente → Genoa_flat.csv
#   ✅ Hellas_Verona.xlsx convertido correctamente → Hellas_Verona_flat.csv
#   ✅ Inter.xlsx convertido correctamente → Inter_flat.csv
#   ✅ Juventus.xlsx convertido correctamente → Juventus_flat.csv
#   ✅ Lazio.xlsx convertido correctamente → Lazio_flat.csv
#   ✅ Lecce.xlsx convertido correctamente → Lecce_flat.csv
#   ✅ Milan.xlsx convertido correctamente → Milan_flat.csv
#   ✅ Monza.xlsx convertido correctamente → Monza_flat.csv
#   ✅ Napoli.xlsx convertido correctamente → Napoli_flat.csv
#   ✅ Parma.xlsx convertido correctamente → Parma_flat.csv
#   ✅ Roma.xlsx convertido correctamente → Roma_flat.csv
#   ✅ Torino.xlsx convertido correctamente → Torino_flat.csv
#   ✅ Udinese.xlsx convertido correctamente → Udinese_flat.csv
#   ✅ Venezia.xlsx convertido correctamente → Venezia_flat.csv

# %%
import os

BASE_PATH = r"D:\Fut_Pred\Data_equipos\2024-2025"

# Recorre todas las carpetas dentro del directorio base
for root, dirs, files in os.walk(BASE_PATH):
    for file in files:
        if file.endswith("_flat.csv"):
            old_path = os.path.join(root, file)
            new_name = file.replace("_flat", "")
            new_path = os.path.join(root, new_name)
            
            # Renombra el archivo
            os.rename(old_path, new_path)
            print(f"Renombrado: {old_path} → {new_path}")

print("\n✅ Proceso completado.")
# Out:
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Augsburg_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Augsburg.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Bayern_Munich_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Bayern_Munich.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Bochum_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Bochum.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Dortmound_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Dortmound.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Eint Frankfurt_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Eint Frankfurt.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Freiburg_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Freiburg.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Gladbach_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Gladbach.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Heidenheim_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Heidenheim.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Hoffenheim_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Hoffenheim.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Holstein_Kiel_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Holstein_Kiel.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Leverkusen_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Alemania\Leverkusen.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Juventus_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Juventus.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Lazio_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Lazio.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Lecce_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Lecce.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Milan_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Milan.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Monza_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Monza.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Napoli_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Napoli.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Parma_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Parma.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Roma_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Roma.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Torino_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Torino.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Udinese_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Udinese.csv
# Renombrado: D:\Fut_Pred\Data_equipos\2024-2025\Italia\Venezia_flat.csv → D:\Fut_Pred\Data_equipos\2024-2025\Italia\Venezia.csv
#
# ✅ Proceso completado.

# %% [markdown]
# # Jugadores

# %% [markdown]
# Inglaterra

# %%
import os
import pandas as pd
# === 1. Carpeta base general de jugadores ===
base_root = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra"

# === 2. Función para limpiar encabezados ===
def clean_col(col):
    parts = [str(c).strip() for c in col if str(c) != 'nan']
    parts = [p for p in parts if not p.startswith('Unnamed')]
    return '_'.join(parts) if parts else 'Unknown'

# === 3. Detección automática del número de niveles de encabezado ===
def detect_header_levels(path):
    preview = pd.read_excel(path, nrows=3, header=None)
    empty_counts = preview.isna().sum().tolist()
    if sum(empty_counts) > len(preview.columns):
        return [0,1,2]
    else:
        return [0,1]

# === 4. Procesar todas las ligas y equipos ===
for league_folder in os.listdir(base_root):
    league_path = os.path.join(base_root, league_folder)
    
    if os.path.isdir(league_path):
        print(f"\n🏟️ Procesando jugadores de la liga: {league_folder}")
        
        for filename in os.listdir(league_path):
            if filename.endswith(".xlsx"):
                input_path = os.path.join(league_path, filename)
                output_path = os.path.join(league_path, filename.replace(".xlsx", "_flat.csv"))

                try:
                    headers = detect_header_levels(input_path)
                    df = pd.read_excel(input_path, header=headers)
                    df.columns = [clean_col(col) for col in df.columns.values]
                    df.to_csv(output_path, index=False, encoding='utf-8-sig')
                    print(f"  ✅ {filename} → {os.path.basename(output_path)}")
                except Exception as e:
                    print(f"  ⚠️ Error procesando {filename}: {e}")
# Out:
# 🏟️ Procesando jugadores de la liga: Arsenal
#   ✅ A1.xlsx → A1_flat.csv
#   ✅ A2.xlsx → A2_flat.csv
#   ✅ A3.xlsx → A3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Aston
#   ✅ Aston1.xlsx → Aston1_flat.csv
#   ✅ Aston2.xlsx → Aston2_flat.csv
#   ✅ Aston3.xlsx → Aston3_flat.csv
#   ✅ Aston4.xlsx → Aston4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Bourth
#   ✅ Bourth1.xlsx → Bourth1_flat.csv
#   ✅ Bourth2.xlsx → Bourth2_flat.csv
#   ✅ Bourth3.xlsx → Bourth3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Brentford
#   ✅ Brent1.xlsx → Brent1_flat.csv
#   ✅ Brent2.xlsx → Brent2_flat.csv
#   ✅ Brent3.xlsx → Brent3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Brighton
#   ✅ Brighton1.xlsx → Brighton1_flat.csv
#   ✅ Brighton2.xlsx → Brighton2_flat.csv
#   ✅ Brighton3.xlsx → Brighton3_flat.csv
#   ✅ Brighton4.xlsx → Brighton4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Chelsea
#   ✅ Chealsea1.xlsx → Chealsea1_flat.csv
#   ✅ Chealsea2.xlsx → Chealsea2_flat.csv
#   ✅ Chealsea3.xlsx → Chealsea3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: City
#   ✅ City1.xlsx → City1_flat.csv
#   ✅ City2.xlsx → City2_flat.csv
#   ✅ City3.xlsx → City3_flat.csv
#   ✅ City4.xlsx → City4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: CR_Palace
#   ✅ CRP1.xlsx → CRP1_flat.csv
#   ✅ CRP2.xlsx → CRP2_flat.csv
#   ✅ CRP3.xlsx → CRP3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Everton
#   ✅ Everton.xlsx → Everton_flat.csv
#   ✅ Everton2.xlsx → Everton2_flat.csv
#   ✅ Everton3.xlsx → Everton3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Forest
#   ✅ Forest1.xlsx → Forest1_flat.csv
#   ✅ Forest2.xlsx → Forest2_flat.csv
#   ✅ Forest3.xlsx → Forest3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Fulham
#   ✅ Fulham1.xlsx → Fulham1_flat.csv
#   ✅ Fulham2.xlsx → Fulham2_flat.csv
#   ✅ Fulham3.xlsx → Fulham3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Ips
#   ✅ Ips1.xlsx → Ips1_flat.csv
#   ✅ Ips2.xlsx → Ips2_flat.csv
#   ✅ Ips3.xlsx → Ips3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Lei
#   ✅ Lei1.xlsx → Lei1_flat.csv
#   ✅ Lei2.xlsx → Lei2_flat.csv
#   ✅ Lei3.xlsx → Lei3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Liverpool
#   ✅ L1.xlsx → L1_flat.csv
#   ✅ L2.xlsx → L2_flat.csv
#   ✅ L3.xlsx → L3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Newcastle
#   ✅ New1.xlsx → New1_flat.csv
#   ✅ New2.xlsx → New2_flat.csv
#   ✅ New3.xlsx → New3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: South
#   ✅ South1.xlsx → South1_flat.csv
#   ✅ South2.xlsx → South2_flat.csv
#   ✅ South3.xlsx → South3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Tote
#   ✅ Toten.xlsx → Toten_flat.csv
#   ✅ Toten2.xlsx → Toten2_flat.csv
#   ✅ Toten3.xlsx → Toten3_flat.csv
#   ✅ Toten4.xlsx → Toten4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: United
#   ✅ United1.xlsx → United1_flat.csv
#   ✅ United2.xlsx → United2_flat.csv
#   ✅ United3.xlsx → United3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: WH
#   ✅ WH1.xlsx → WH1_flat.csv
#   ✅ WH2.xlsx → WH2_flat.csv
#   ✅ WH3.xlsx → WH3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Wolves
#   ✅ Wolves1.xlsx → Wolves1_flat.csv
#   ✅ Wolves2.xlsx → Wolves2_flat.csv
#   ✅ Wolves3.xlsx → Wolves3_flat.csv

# %% [markdown]
# Alemania

# %%
import os
import pandas as pd
# === 1. Carpeta base general de jugadores ===
base_root = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania"

# === 2. Función para limpiar encabezados ===
def clean_col(col):
    parts = [str(c).strip() for c in col if str(c) != 'nan']
    parts = [p for p in parts if not p.startswith('Unnamed')]
    return '_'.join(parts) if parts else 'Unknown'

# === 3. Detección automática del número de niveles de encabezado ===
def detect_header_levels(path):
    preview = pd.read_excel(path, nrows=3, header=None)
    empty_counts = preview.isna().sum().tolist()
    if sum(empty_counts) > len(preview.columns):
        return [0,1,2]
    else:
        return [0,1]

# === 4. Procesar todas las ligas y equipos ===
for league_folder in os.listdir(base_root):
    league_path = os.path.join(base_root, league_folder)
    
    if os.path.isdir(league_path):
        print(f"\n🏟️ Procesando jugadores de la liga: {league_folder}")
        
        for filename in os.listdir(league_path):
            if filename.endswith(".xlsx"):
                input_path = os.path.join(league_path, filename)
                output_path = os.path.join(league_path, filename.replace(".xlsx", "_flat.csv"))

                try:
                    headers = detect_header_levels(input_path)
                    df = pd.read_excel(input_path, header=headers)
                    df.columns = [clean_col(col) for col in df.columns.values]
                    df.to_csv(output_path, index=False, encoding='utf-8-sig')
                    print(f"  ✅ {filename} → {os.path.basename(output_path)}")
                except Exception as e:
                    print(f"  ⚠️ Error procesando {filename}: {e}")
# Out:
# 🏟️ Procesando jugadores de la liga: Augsburg
#   ✅ Aus1.xlsx → Aus1_flat.csv
#   ✅ Aus2.xlsx → Aus2_flat.csv
#   ✅ Aus3.xlsx → Aus3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Bayern_Munich
#   ✅ Munich1.xlsx → Munich1_flat.csv
#   ✅ Munich2.xlsx → Munich2_flat.csv
#   ✅ Munich3.xlsx → Munich3_flat.csv
#   ✅ Munich4.xlsx → Munich4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Bayer_Leverkusen
#   ✅ Lev1.xlsx → Lev1_flat.csv
#   ✅ Lev2.xlsx → Lev2_flat.csv
#   ✅ Lev3.xlsx → Lev3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Bochum_1848
#   ✅ Bouch1.xlsx → Bouch1_flat.csv
#   ✅ Bouch2.xlsx → Bouch2_flat.csv
#   ✅ Bouch3.xlsx → Bouch3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Borussia_Dortmund
#   ✅ Dort1.xlsx → Dort1_flat.csv
#   ✅ Dort2.xlsx → Dort2_flat.csv
#   ✅ Dort3.xlsx → Dort3_flat.csv
#   ✅ Dort4.xlsx → Dort4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Borussia_Monchengladbach
#   ✅ Monch1.xlsx → Monch1_flat.csv
#   ✅ Monch2.xlsx → Monch2_flat.csv
#   ✅ Monch3.xlsx → Monch3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Frankfurt
#   ✅ Frank1.xlsx → Frank1_flat.csv
#   ✅ Frank2.xlsx → Frank2_flat.csv
#   ✅ Frank3.xlsx → Frank3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Freiburg
#   ✅ Freib1.xlsx → Freib1_flat.csv
#   ✅ Freib2.xlsx → Freib2_flat.csv
#   ✅ Freib3.xlsx → Freib3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Heidenheim_1846
#   ✅ Hei1.xlsx → Hei1_flat.csv
#   ✅ Hei2.xlsx → Hei2_flat.csv
#   ✅ Hei3.xlsx → Hei3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Hoffenheim
#   ✅ Hoff1.xlsx → Hoff1_flat.csv
#   ✅ Hoff2.xlsx → Hoff2_flat.csv
#   ✅ Hoff3.xlsx → Hoff3_flat.csv
#   ✅ Hoff4.xlsx → Hoff4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Holstein_Kiel
#   ✅ Hols1.xlsx → Hols1_flat.csv
#   ✅ Hols2.xlsx → Hols2_flat.csv
#   ✅ Hols3.xlsx → Hols3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Mainz_05
#   ✅ Mainz1.xlsx → Mainz1_flat.csv
#   ✅ Mainz2.xlsx → Mainz2_flat.csv
#   ✅ Mainz3.xlsx → Mainz3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: RB_Leipzig
#   ✅ Leipz1.xlsx → Leipz1_flat.csv
#   ✅ Leipz2.xlsx → Leipz2_flat.csv
#   ✅ Leipz3.xlsx → Leipz3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: St.Pauli
#   ✅ Pau1.xlsx → Pau1_flat.csv
#   ✅ Pau2.xlsx → Pau2_flat.csv
#   ✅ Pau3.xlsx → Pau3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Stuttgart
#   ✅ Stutt1.xlsx → Stutt1_flat.csv
#   ✅ Stutt2.xlsx → Stutt2_flat.csv
#   ✅ Stutt3.xlsx → Stutt3_flat.csv
#   ✅ Stutt4.xlsx → Stutt4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Union_Berlin
#   ✅ Ber1.xlsx → Ber1_flat.csv
#   ✅ Ber2.xlsx → Ber2_flat.csv
#   ✅ Ber3.xlsx → Ber3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Werder_Bremen
#   ✅ Wer1.xlsx → Wer1_flat.csv
#   ✅ Wer2.xlsx → Wer2_flat.csv
#   ✅ Wer3.xlsx → Wer3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Wolfsburg
#   ✅ Wolf1.xlsx → Wolf1_flat.csv
#   ✅ Wolf2.xlsx → Wolf2_flat.csv
#   ✅ Wolf3.xlsx → Wolf3_flat.csv

# %% [markdown]
# Italia

# %%
import os
import pandas as pd
# === 1. Carpeta base general de jugadores ===
base_root = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Italia"

# === 2. Función para limpiar encabezados ===
def clean_col(col):
    parts = [str(c).strip() for c in col if str(c) != 'nan']
    parts = [p for p in parts if not p.startswith('Unnamed')]
    return '_'.join(parts) if parts else 'Unknown'

# === 3. Detección automática del número de niveles de encabezado ===
def detect_header_levels(path):
    preview = pd.read_excel(path, nrows=3, header=None)
    empty_counts = preview.isna().sum().tolist()
    if sum(empty_counts) > len(preview.columns):
        return [0,1,2]
    else:
        return [0,1]

# === 4. Procesar todas las ligas y equipos ===
for league_folder in os.listdir(base_root):
    league_path = os.path.join(base_root, league_folder)
    
    if os.path.isdir(league_path):
        print(f"\n🏟️ Procesando jugadores de la liga: {league_folder}")
        
        for filename in os.listdir(league_path):
            if filename.endswith(".xlsx"):
                input_path = os.path.join(league_path, filename)
                output_path = os.path.join(league_path, filename.replace(".xlsx", "_flat.csv"))

                try:
                    headers = detect_header_levels(input_path)
                    df = pd.read_excel(input_path, header=headers)
                    df.columns = [clean_col(col) for col in df.columns.values]
                    df.to_csv(output_path, index=False, encoding='utf-8-sig')
                    print(f"  ✅ {filename} → {os.path.basename(output_path)}")
                except Exception as e:
                    print(f"  ⚠️ Error procesando {filename}: {e}")
# Out:
# 🏟️ Procesando jugadores de la liga: AC_Milan
#   ✅ Milan1.xlsx → Milan1_flat.csv
#   ✅ Milan2.xlsx → Milan2_flat.csv
#   ✅ Milan3.xlsx → Milan3_flat.csv
#   ✅ Milan4.xlsx → Milan4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Atalanta
#   ✅ At1.xlsx → At1_flat.csv
#   ✅ At2.xlsx → At2_flat.csv
#   ✅ At3.xlsx → At3_flat.csv
#   ✅ At4.xlsx → At4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Bologna
#   ✅ Bo1.xlsx → Bo1_flat.csv
#   ✅ Bo2.xlsx → Bo2_flat.csv
#   ✅ Bo3.xlsx → Bo3_flat.csv
#   ✅ Bo4.xlsx → Bo4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Cagliari
#   ✅ Cag1.xlsx → Cag1_flat.csv
#   ✅ Cag2.xlsx → Cag2_flat.csv
#   ✅ Cag3.xlsx → Cag3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Como
#   ✅ Como1.xlsx → Como1_flat.csv
#   ✅ Como2.xlsx → Como2_flat.csv
#   ✅ Como3.xlsx → Como3_flat.csv
#   ✅ Como4.xlsx → Como4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Empoli
#   ✅ emp1.xlsx → emp1_flat.csv
#   ✅ emp2.xlsx → emp2_flat.csv
#   ✅ emp3.xlsx → emp3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Fiorentina
#   ✅ Fio1.xlsx → Fio1_flat.csv
#   ✅ Fio2.xlsx → Fio2_flat.csv
#   ✅ Fio3.xlsx → Fio3_flat.csv
#   ✅ Fio4.xlsx → Fio4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Genoa
#   ✅ Geo1.xlsx → Geo1_flat.csv
#   ✅ Geo2.xlsx → Geo2_flat.csv
#   ✅ Geo3.xlsx → Geo3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Hellas_Verona
#   ✅ Hellas1.xlsx → Hellas1_flat.csv
#   ✅ Helllas2.xlsx → Helllas2_flat.csv
#   ✅ Helllas3.xlsx → Helllas3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Inter_Milan
#   ✅ Inter1.xlsx → Inter1_flat.csv
#   ✅ Inter2.xlsx → Inter2_flat.csv
#   ✅ Inter3.xlsx → Inter3_flat.csv
#   ✅ Inter4.xlsx → Inter4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Juventus
#   ✅ Ju1.xlsx → Ju1_flat.csv
#   ✅ Ju2.xlsx → Ju2_flat.csv
#   ✅ Ju3.xlsx → Ju3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Lazio
#   ✅ La1.xlsx → La1_flat.csv
#   ✅ La2.xlsx → La2_flat.csv
#   ✅ La3.xlsx → La3_flat.csv
#   ✅ La4.xlsx → La4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Lecce
#   ✅ Lecce1.xlsx → Lecce1_flat.csv
#   ✅ Lecce2.xlsx → Lecce2_flat.csv
#   ✅ Lecce3.xlsx → Lecce3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Monza
#   ✅ Mon1.xlsx → Mon1_flat.csv
#   ✅ Mon2.xlsx → Mon2_flat.csv
#   ✅ Mon3.xlsx → Mon3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Napoli
#   ✅ Nap1.xlsx → Nap1_flat.csv
#   ✅ Nap2.xlsx → Nap2_flat.csv
#   ✅ Nap3.xlsx → Nap3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Parma
#   ✅ Parma1.xlsx → Parma1_flat.csv
#   ✅ Parma2.xlsx → Parma2_flat.csv
#   ✅ Parma3.xlsx → Parma3_flat.csv
#   ✅ Parma4.xlsx → Parma4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Roma
#   ✅ Ro1.xlsx → Ro1_flat.csv
#   ✅ Ro2.xlsx → Ro2_flat.csv
#   ✅ Ro3.xlsx → Ro3_flat.csv
#   ✅ Ro4.xlsx → Ro4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Torino
#   ✅ To1.xlsx → To1_flat.csv
#   ✅ To2.xlsx → To2_flat.csv
#   ✅ To3.xlsx → To3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Udinese
#   ✅ Udi1.xlsx → Udi1_flat.csv
#   ✅ Udi2.xlsx → Udi2_flat.csv
#   ✅ Udi3.xlsx → Udi3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Venezia
#   ✅ Venezia.xlsx → Venezia_flat.csv
#   ✅ Venezia2.xlsx → Venezia2_flat.csv
#   ✅ Venezia3.xlsx → Venezia3_flat.csv
#   ✅ Venezia4.xlsx → Venezia4_flat.csv

# %% [markdown]
# Francia

# %%
import os
import pandas as pd
# === 1. Carpeta base general de jugadores ===
base_root = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Francia"

# === 2. Función para limpiar encabezados ===
def clean_col(col):
    parts = [str(c).strip() for c in col if str(c) != 'nan']
    parts = [p for p in parts if not p.startswith('Unnamed')]
    return '_'.join(parts) if parts else 'Unknown'

# === 3. Detección automática del número de niveles de encabezado ===
def detect_header_levels(path):
    preview = pd.read_excel(path, nrows=3, header=None)
    empty_counts = preview.isna().sum().tolist()
    if sum(empty_counts) > len(preview.columns):
        return [0,1,2]
    else:
        return [0,1]

# === 4. Procesar todas las ligas y equipos ===
for league_folder in os.listdir(base_root):
    league_path = os.path.join(base_root, league_folder)
    
    if os.path.isdir(league_path):
        print(f"\n🏟️ Procesando jugadores de la liga: {league_folder}")
        
        for filename in os.listdir(league_path):
            if filename.endswith(".xlsx"):
                input_path = os.path.join(league_path, filename)
                output_path = os.path.join(league_path, filename.replace(".xlsx", "_flat.csv"))

                try:
                    headers = detect_header_levels(input_path)
                    df = pd.read_excel(input_path, header=headers)
                    df.columns = [clean_col(col) for col in df.columns.values]
                    df.to_csv(output_path, index=False, encoding='utf-8-sig')
                    print(f"  ✅ {filename} → {os.path.basename(output_path)}")
                except Exception as e:
                    print(f"  ⚠️ Error procesando {filename}: {e}")
# Out:
# 🏟️ Procesando jugadores de la liga: Angers
#   ✅ Ang1.xlsx → Ang1_flat.csv
#   ✅ Ang2.xlsx → Ang2_flat.csv
#   ✅ Ang3.xlsx → Ang3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: As_monaco
#   ✅ Mona1.xlsx → Mona1_flat.csv
#   ✅ Mona2.xlsx → Mona2_flat.csv
#   ✅ Mona3.xlsx → Mona3_flat.csv
#   ✅ Mona4.xlsx → Mona4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Auxerre
#   ✅ Aux1.xlsx → Aux1_flat.csv
#   ✅ Aux2.xlsx → Aux2_flat.csv
#   ✅ Aux3.xlsx → Aux3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Brest
#   ✅ Brest1.xlsx → Brest1_flat.csv
#   ✅ Brest2.xlsx → Brest2_flat.csv
#   ✅ Brest3.xlsx → Brest3_flat.csv
#   ✅ Brest4.xlsx → Brest4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Lens
#   ✅ Lens1.xlsx → Lens1_flat.csv
#   ✅ Lens2.xlsx → Lens2_flat.csv
#   ✅ Lens3.xlsx → Lens3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Le_Havre
#   ✅ Le1.xlsx → Le1_flat.csv
#   ✅ Le2.xlsx → Le2_flat.csv
#   ✅ Le3.xlsx → Le3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Lille
#   ✅ Lil1.xlsx → Lil1_flat.csv
#   ✅ Lil2.xlsx → Lil2_flat.csv
#   ✅ Lil3.xlsx → Lil3_flat.csv
#   ✅ Lil4.xlsx → Lil4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Lyon
#   ✅ Lyon1.xlsx → Lyon1_flat.csv
#   ✅ Lyon2.xlsx → Lyon2_flat.csv
#   ✅ Lyon3.xlsx → Lyon3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Marseille
#   ✅ Marse1.xlsx → Marse1_flat.csv
#   ✅ Marse2.xlsx → Marse2_flat.csv
#   ✅ Marse3.xlsx → Marse3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Montpellier
#   ✅ Monp1.xlsx → Monp1_flat.csv
#   ✅ Monp2.xlsx → Monp2_flat.csv
#   ✅ Monp3.xlsx → Monp3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Nantes
#   ✅ Nan1.xlsx → Nan1_flat.csv
#   ✅ Nan2.xlsx → Nan2_flat.csv
#   ✅ Nan3.xlsx → Nan3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Nice
#   ✅ Nic1.xlsx → Nic1_flat.csv
#   ✅ Nic2.xlsx → Nic2_flat.csv
#   ✅ Nic3.xlsx → Nic3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: PSG
#   ✅ psg1.xlsx → psg1_flat.csv
#   ✅ psg2.xlsx → psg2_flat.csv
#   ✅ psg3.xlsx → psg3_flat.csv
#   ✅ psg4.xlsx → psg4_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Reims
#   ✅ Reim1.xlsx → Reim1_flat.csv
#   ✅ Reim2.xlsx → Reim2_flat.csv
#   ✅ Reim3.xlsx → Reim3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Rennes
#   ✅ ren1.xlsx → ren1_flat.csv
#   ✅ ren2.xlsx → ren2_flat.csv
#   ✅ ren3.xlsx → ren3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Saint_Etienne
#   ✅ saint1.xlsx → saint1_flat.csv
#   ✅ saint2.xlsx → saint2_flat.csv
#   ✅ saint3.xlsx → saint3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Strasbourg
#   ✅ Stras1.xlsx → Stras1_flat.csv
#   ✅ Stras2.xlsx → Stras2_flat.csv
#   ✅ Stras3.xlsx → Stras3_flat.csv
#
# 🏟️ Procesando jugadores de la liga: Toulouse
#   ✅ Tou1.xlsx → Tou1_flat.csv
#   ✅ Tou2.xlsx → Tou2_flat.csv
#   ✅ Tou3.xlsx → Tou3_flat.csv
