# %%
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# Inglaterra

# %%
import pandas as pd
import os
from pathlib import Path

# === Ruta base donde están las carpetas de los equipos ===
base_path = Path(r"D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra")  # <-- cámbiala a la tuya

# === Carpeta donde se guardarán los archivos combinados ===
output_folder = base_path / "Combinados"
output_folder.mkdir(exist_ok=True)

# === Recorre todas las carpetas dentro de la ruta base ===
for folder in base_path.iterdir():
    if folder.is_dir():
        csv_files = list(folder.glob("*.csv"))

        if not csv_files:
            print(f"⚠️ No hay archivos CSV en {folder.name}, se omite.")
            continue

        print(f"📂 Combinando archivos en: {folder.name} ({len(csv_files)} archivos)")

        # Leer y concatenar todos los CSV
        dfs = []
        for f in csv_files:
            df = pd.read_csv(f)
            dfs.append(df)

        combined_df = pd.concat(dfs, ignore_index=True)

        # Guardar con el nombre de la carpeta
        output_path = output_folder / f"{folder.name}.csv"
        combined_df.to_csv(output_path, index=False, encoding="utf-8-sig")

        print(f"✅ Guardado: {output_path}")

print("\n🎉 ¡Proceso terminado!")
# Out:
# 📂 Combinando archivos en: Arsenal (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\Arsenal.csv
# 📂 Combinando archivos en: Aston (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\Aston.csv
# 📂 Combinando archivos en: Bourth (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\Bourth.csv
# 📂 Combinando archivos en: Brentford (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\Brentford.csv
# 📂 Combinando archivos en: Brighton (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\Brighton.csv
# 📂 Combinando archivos en: Chelsea (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\Chelsea.csv
# 📂 Combinando archivos en: City (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados\City.csv
# 📂 Combinando archivos en: Combinados (7 archivos)
# ...

# %% [markdown]
# Alemania

# %%
import pandas as pd
import os
from pathlib import Path

# === Ruta base donde están las carpetas de los equipos ===
base_path = Path(r"D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania")  # <-- cámbiala a la tuya

# === Carpeta donde se guardarán los archivos combinados ===
output_folder = base_path / "Combinados"
output_folder.mkdir(exist_ok=True)

# === Recorre todas las carpetas dentro de la ruta base ===
for folder in base_path.iterdir():
    if folder.is_dir():
        csv_files = list(folder.glob("*.csv"))

        if not csv_files:
            print(f"⚠️ No hay archivos CSV en {folder.name}, se omite.")
            continue

        print(f"📂 Combinando archivos en: {folder.name} ({len(csv_files)} archivos)")

        # Leer y concatenar todos los CSV
        dfs = []
        for f in csv_files:
            df = pd.read_csv(f)
            dfs.append(df)

        combined_df = pd.concat(dfs, ignore_index=True)

        # Guardar con el nombre de la carpeta
        output_path = output_folder / f"{folder.name}.csv"
        combined_df.to_csv(output_path, index=False, encoding="utf-8-sig")

        print(f"✅ Guardado: {output_path}")

print("\n🎉 ¡Proceso terminado!")
# Out:
# 📂 Combinando archivos en: Augsburg (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados\Augsburg.csv
# 📂 Combinando archivos en: Bayern_Munich (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados\Bayern_Munich.csv
# 📂 Combinando archivos en: Bayer_Leverkusen (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados\Bayer_Leverkusen.csv
# 📂 Combinando archivos en: Bochum_1848 (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados\Bochum_1848.csv
# 📂 Combinando archivos en: Borussia_Dortmund (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados\Borussia_Dortmund.csv
# 📂 Combinando archivos en: Borussia_Monchengladbach (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados\Borussia_Monchengladbach.csv
# 📂 Combinando archivos en: Combinados (6 archivos)
# ...

# %% [markdown]
# Italia

# %%
import pandas as pd
import os
from pathlib import Path

# === Ruta base donde están las carpetas de los equipos ===
base_path = Path(r"D:\Fut_Pred\Datos_jugadores\2024-2025\Italia")  # <-- cámbiala a la tuya

# === Carpeta donde se guardarán los archivos combinados ===
output_folder = base_path / "Combinados"
output_folder.mkdir(exist_ok=True)

# === Recorre todas las carpetas dentro de la ruta base ===
for folder in base_path.iterdir():
    if folder.is_dir():
        csv_files = list(folder.glob("*.csv"))

        if not csv_files:
            print(f"⚠️ No hay archivos CSV en {folder.name}, se omite.")
            continue

        print(f"📂 Combinando archivos en: {folder.name} ({len(csv_files)} archivos)")

        # Leer y concatenar todos los CSV
        dfs = []
        for f in csv_files:
            df = pd.read_csv(f)
            dfs.append(df)

        combined_df = pd.concat(dfs, ignore_index=True)

        # Guardar con el nombre de la carpeta
        output_path = output_folder / f"{folder.name}.csv"
        combined_df.to_csv(output_path, index=False, encoding="utf-8-sig")

        print(f"✅ Guardado: {output_path}")

print("\n🎉 ¡Proceso terminado!")
# Out:
# 📂 Combinando archivos en: AC_Milan (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\AC_Milan.csv
# 📂 Combinando archivos en: Atalanta (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\Atalanta.csv
# 📂 Combinando archivos en: Bologna (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\Bologna.csv
# 📂 Combinando archivos en: Cagliari (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\Cagliari.csv
# 📂 Combinando archivos en: Combinados (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\Combinados.csv
# 📂 Combinando archivos en: Como (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\Como.csv
# 📂 Combinando archivos en: Empoli (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados\Empoli.csv
# 📂 Combinando archivos en: Fiorentina (4 archivos)
# ...

# %% [markdown]
# Francia

# %%
import pandas as pd
import os
from pathlib import Path

# === Ruta base donde están las carpetas de los equipos ===
base_path = Path(r"D:\Fut_Pred\Datos_jugadores\2024-2025\Francia")  # <-- cámbiala a la tuya

# === Carpeta donde se guardarán los archivos combinados ===
output_folder = base_path / "Combinados"
output_folder.mkdir(exist_ok=True)

# === Recorre todas las carpetas dentro de la ruta base ===
for folder in base_path.iterdir():
    if folder.is_dir():
        csv_files = list(folder.glob("*.csv"))

        if not csv_files:
            print(f"⚠️ No hay archivos CSV en {folder.name}, se omite.")
            continue

        print(f"📂 Combinando archivos en: {folder.name} ({len(csv_files)} archivos)")

        # Leer y concatenar todos los CSV
        dfs = []
        for f in csv_files:
            df = pd.read_csv(f)
            dfs.append(df)

        combined_df = pd.concat(dfs, ignore_index=True)

        # Guardar con el nombre de la carpeta
        output_path = output_folder / f"{folder.name}.csv"
        combined_df.to_csv(output_path, index=False, encoding="utf-8-sig")

        print(f"✅ Guardado: {output_path}")

print("\n🎉 ¡Proceso terminado!")
# Out:
# 📂 Combinando archivos en: Angers (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\Angers.csv
# 📂 Combinando archivos en: As_monaco (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\As_monaco.csv
# 📂 Combinando archivos en: Auxerre (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\Auxerre.csv
# 📂 Combinando archivos en: Brest (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\Brest.csv
# 📂 Combinando archivos en: Combinados (4 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\Combinados.csv
# 📂 Combinando archivos en: Lens (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\Lens.csv
# 📂 Combinando archivos en: Le_Havre (3 archivos)
# ✅ Guardado: D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados\Le_Havre.csv
# 📂 Combinando archivos en: Lille (4 archivos)
# ...
