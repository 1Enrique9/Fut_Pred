# %% [markdown]
# # Librerias

# %%
import pandas as pd
from sqlalchemy import create_engine, text
from glob import glob
import os
import re

# %% [markdown]
# # Conexion

# %%
# Datos de conexión
user = "root"
password = "Levp13aa"
host = "localhost"
database = "futbol_dw"

# Crear conexión
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{database}")

# Probar conexión
with engine.connect() as conn:
    result = conn.execute(text("SELECT 'Conexión exitosa a MySQL!' AS mensaje;"))
    print(result.fetchone())
# Out:
# ('Conexión exitosa a MySQL!',)

# %% [markdown]
# # Bronze

# %% [markdown]
# ### Equipos

# %% [markdown]
# Evitar los duplicados, o dobles tablas

# %%
with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS bronze_teams;"))
    conn.commit()
print("Tabla 'bronze_teams' eliminada correctamente.\n")
# Out:
# Tabla 'bronze_teams' eliminada correctamente.

# %% [markdown]
# España

# %%
#  Carpeta con los CSV 
folder_path = r"D:\Fut_Pred\Data_equipos\2024-2025\España"
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f" Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar nombres 
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)  
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

# Cargar archivos 
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")
        df.columns = [clean_column_name(c) for c in df.columns]

        # Eliminar duplicados de encabezados
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Laliga"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Subir a MySQL
        df.to_sql("bronze_teams", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n🏁 Proceso completado: equipos de España cargados correctamente en 'bronze_teams'")
# Out:
#  Se encontraron 20 archivos en D:\Fut_Pred\Data_equipos\2024-2025\España
#
#  Cargado: Alaves.csv (38 filas)
#  Cargado: Athletic_Club.csv (38 filas)
#  Cargado: Atletico_Madrid.csv (48 filas)
#  Cargado: Celta_Vigo.csv (38 filas)
#  Cargado: Espayol.csv (38 filas)
#  Cargado: FC_Barcelona.csv (52 filas)
#  Cargado: Getafe.csv (38 filas)
#  Cargado: Girona.csv (38 filas)
#  Cargado: Las_Palmas.csv (38 filas)
#  Cargado: Leganes.csv (38 filas)
#  Cargado: Mallorca.csv (38 filas)
#  Cargado: Osasuna.csv (38 filas)
#  Cargado: Rayo_Vallecano.csv (38 filas)
#  Cargado: Real_Betis.csv (38 filas)
#  Cargado: Real_Madrid.csv (38 filas)
#  Cargado: Real_Sociedad.csv (50 filas)
#  Cargado: Real_Valladolid.csv (38 filas)
#  Cargado: Sevilla.csv (38 filas)
#  Cargado: Valencia.csv (38 filas)
#  Cargado: Villareal.csv (38 filas)
#
# 🏁 Proceso completado: equipos de España cargados correctamente en 'bronze_teams'

# %% [markdown]
# Inglaterra

# %%
#  Carpeta con los CSV 
folder_path = r"D:\Fut_Pred\Data_equipos\2024-2025\Inglaterra"
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f" Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar nombres 
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)  
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

# Cargar archivos 
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")
        df.columns = [clean_column_name(c) for c in df.columns]

        # Eliminar duplicados de encabezados
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Premier_League"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Subir a MySQL
        df.to_sql("bronze_teams", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: equipos de Inglaterra cargados correctamente en 'bronze_teams'")
# Out:
#  Se encontraron 20 archivos en D:\Fut_Pred\Data_equipos\2024-2025\Inglaterra
#
#  Cargado: Arsenal.csv (52 filas)
#  Cargado: Aston_Villa.csv (50 filas)
#  Cargado: Bournemouth.csv (38 filas)
#  Cargado: Brentford.csv (38 filas)
#  Cargado: Brighton.csv (38 filas)
#  Cargado: Chelsea.csv (51 filas)
#  Cargado: Crystal_Palace.csv (38 filas)
#  Cargado: Everton.csv (38 filas)
#  Cargado: Fulham.csv (38 filas)
#  Cargado: Ipswich_Town.csv (38 filas)
#  Cargado: Leicester.csv (38 filas)
#  Cargado: Liverpool.csv (38 filas)
#  Cargado: Manchester_city.csv (48 filas)
#  Cargado: Manchester_united.csv (38 filas)
#  Cargado: Newcastle.csv (38 filas)
#  Cargado: Nothingham_Forest.csv (38 filas)
#  Cargado: Southampton.csv (38 filas)
#  Cargado: Tottenham.csv (38 filas)
#  Cargado: West_Ham.csv (38 filas)
#  Cargado: Wolves.csv (38 filas)
#
#  Proceso completado: equipos de Inglaterra cargados correctamente en 'bronze_teams'

# %%
#  Carpeta con los CSV 
folder_path = r"D:\Fut_Pred\Data_equipos\2024-2025\Alemania"
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f" Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar nombres 
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)  
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

# Cargar archivos 
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")
        df.columns = [clean_column_name(c) for c in df.columns]

        # Eliminar duplicados de encabezados
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Bundesliga"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Subir a MySQL
        df.to_sql("bronze_teams", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: equipos de Alemania cargados correctamente en 'bronze_teams'")
# Out:
#  Se encontraron 18 archivos en D:\Fut_Pred\Data_equipos\2024-2025\Alemania
#
#  Cargado: Augsburg.csv (34 filas)
#  Cargado: Bayern_Munich.csv (48 filas)
#  Cargado: Bochum.csv (34 filas)
#  Cargado: Dortmound.csv (48 filas)
#  Cargado: Eint Frankfurt.csv (34 filas)
#  Cargado: Freiburg.csv (34 filas)
#  Cargado: Gladbach.csv (34 filas)
#  Cargado: Heidenheim.csv (34 filas)
#  Cargado: Hoffenheim.csv (34 filas)
#  Cargado: Holstein_Kiel.csv (34 filas)
#  Cargado: Leverkusen.csv (44 filas)
#  Cargado: Mainz_05.csv (34 filas)
#  Cargado: RB_Leipzig.csv (42 filas)
#  Cargado: St. Pauli.csv (34 filas)
#  Cargado: Stuttgart.csv (42 filas)
#  Cargado: Union_Berlin.csv (34 filas)
#  Cargado: Werder_Bremen.csv (34 filas)
#  Cargado: Wolfsburg.csv (34 filas)
#
#  Proceso completado: equipos de Alemania cargados correctamente en 'bronze_teams'

# %% [markdown]
# Italia

# %%
#  Carpeta con los CSV 
folder_path = r"D:\Fut_Pred\Data_equipos\2024-2025\Italia"
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f" Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar nombres 
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)  
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

# Cargar archivos 
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")
        df.columns = [clean_column_name(c) for c in df.columns]

        # Eliminar duplicados de encabezados
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Serie_A"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Subir a MySQL
        df.to_sql("bronze_teams", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: equipos de Italia cargados correctamente en 'bronze_teams'")
# Out:
#  Se encontraron 20 archivos en D:\Fut_Pred\Data_equipos\2024-2025\Italia
#
#  Cargado: Atalanta.csv (38 filas)
#  Cargado: Bologna.csv (46 filas)
#  Cargado: Cagliari.csv (38 filas)
#  Cargado: Como.csv (38 filas)
#  Cargado: Empoli.csv (38 filas)
#  Cargado: Fiorentina.csv (50 filas)
#  Cargado: Genoa.csv (38 filas)
#  Cargado: Hellas_Verona.csv (38 filas)
#  Cargado: Inter.csv (53 filas)
#  Cargado: Juventus.csv (38 filas)
#  Cargado: Lazio.csv (50 filas)
#  Cargado: Lecce.csv (38 filas)
#  Cargado: Milan.csv (38 filas)
#  Cargado: Monza.csv (38 filas)
#  Cargado: Napoli.csv (38 filas)
#  Cargado: Parma.csv (38 filas)
#  Cargado: Roma.csv (38 filas)
#  Cargado: Torino.csv (38 filas)
#  Cargado: Udinese.csv (38 filas)
#  Cargado: Venezia.csv (38 filas)
#
#  Proceso completado: equipos de Italia cargados correctamente en 'bronze_teams'

# %% [markdown]
# Francia

# %%
#  Carpeta con los CSV 
folder_path = r"D:\Fut_Pred\Data_equipos\2024-2025\Francia"
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f" Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar nombres 
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)  
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

# Cargar archivos 
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")
        df.columns = [clean_column_name(c) for c in df.columns]

        # Eliminar duplicados de encabezados
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Ligue_1"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Subir a MySQL
        df.to_sql("bronze_teams", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: equipos de Francia cargados correctamente en 'bronze_teams'")
# Out:
#  Se encontraron 18 archivos en D:\Fut_Pred\Data_equipos\2024-2025\Francia
#
#  Cargado: Angers.csv (34 filas)
#  Cargado: Auxerre.csv (34 filas)
#  Cargado: Brest.csv (44 filas)
#  Cargado: Lens.csv (34 filas)
#  Cargado: Le_Havre.csv (34 filas)
#  Cargado: Lille.csv (44 filas)
#  Cargado: Lyon.csv (34 filas)
#  Cargado: Marseille.csv (34 filas)
#  Cargado: Monaco.csv (34 filas)
#  Cargado: Montpellier.csv (33 filas)
#  Cargado: Nantes.csv (34 filas)
#  Cargado: Nice.csv (34 filas)
#  Cargado: PSG.csv (34 filas)
#  Cargado: Reims.csv (34 filas)
#  Cargado: Rennes.csv (34 filas)
#  Cargado: Saint-Étienne.csv (33 filas)
#  Cargado: Strasbourg.csv (34 filas)
#  Cargado: Toulouse.csv (34 filas)
#
#  Proceso completado: equipos de Francia cargados correctamente en 'bronze_teams'

# %%
query = """
SELECT team_name, COUNT(*) AS registros, MIN(Date) AS primer_partido, MAX(Date) AS ultimo_partido
FROM bronze_teams
WHERE league = 'Ligue_1'
GROUP BY team_name
ORDER BY team_name;
"""
pd.read_sql(query, engine)
# Out:
#         team_name  registros primer_partido ultimo_partido
# 0          Angers         34     2024-08-18     2025-05-17
# 1         Auxerre         34     2024-08-18     2025-05-17
# 2           Brest         44     2024-08-17     2025-05-17
# 3        Le_Havre         34     2024-08-16     2025-05-17
# 4            Lens         34     2024-08-18     2025-05-17
# 5           Lille         44     2024-08-17     2025-05-17
# 6            Lyon         34     2024-09-20     2025-05-16
# 7       Marseille         34     2024-08-17     2025-05-17
# 8          Monaco         34     2024-08-17     2025-05-17
# 9     Montpellier         33     2024-08-18     2025-05-17
# 10         Nantes         34     2024-08-18     2025-05-17
# 11           Nice         34     2024-08-18     2025-05-17
# 12            PSG         34     2024-08-16     2025-05-17
# 13          Reims         34     2024-08-17     2025-05-17
# 14         Rennes         34     2024-08-18     2025-05-17
# ...

# %% [markdown]
# ### Jugadores

# %%
with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS bronze_players;"))
    conn.commit()
print(" Tabla 'bronze_players' eliminada correctamente.\n")
# Out:
#  Tabla 'bronze_players' eliminada correctamente.

# %% [markdown]
# Valor de Mercado

# %%
csv_path = r"D:\Fut_Pred\Transfermrkt.csv" 

# === 3. Leer el CSV y limpiar encabezados ===
df = pd.read_csv(csv_path, encoding='utf-8')

def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

df.columns = [clean_column_name(c) for c in df.columns]

# === 4. Normalizar texto (importante para futuros joins) ===
if 'Name' in df.columns:
    df['Name'] = df['Name'].astype(str).str.lower().str.strip()
if 'Team' in df.columns:
    df['Team'] = df['Team'].astype(str).str.lower().str.strip()

# === 5. Subir a MySQL ===
df.to_sql("bronze_player_market", engine, if_exists="replace", index=False, method="multi", chunksize=1000)

print(f"✅ Tabla 'bronze_player_market' creada correctamente con {len(df)} filas y {len(df.columns)} columnas.")
# Out:
# ✅ Tabla 'bronze_player_market' creada correctamente con 2600 filas y 11 columnas.

# %% [markdown]
# # Jugadores

# %%
#  Carpeta con los CSV de jugadores 
folder_path = r"D:\Fut_Pred\Datos_jugadores\2024-2025\España"  
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f"🔍 Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar encabezados
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

#  Cargar archivos
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")

        # Limpieza de encabezados
        df.columns = [clean_column_name(c) for c in df.columns]
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Laliga"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Cargar en MySQL
        df.to_sql("bronze_players", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: jugadores de España cargados en 'bronze_players'")
# Out:
# 🔍 Se encontraron 20 archivos en D:\Fut_Pred\Datos_jugadores\2024-2025\España
#
#  Cargado: Alaves_flat.csv (579 filas)
#  Cargado: Athletic_Club_flat.csv (829 filas)
#  Cargado: Atletico_Madrid_flat.csv (764 filas)
#  Cargado: Celta_vigo_flat.csv (607 filas)
#  Cargado: Espanyol_flat.csv (598 filas)
#  Cargado: FC_Barcelona _flat.csv (820 filas)
#  Cargado: Getafe_flat.csv (582 filas)
#  Cargado: Girona_flat.csv (714 filas)
#  Cargado: Las_Palmas_flat.csv (607 filas)
#  Cargado: Leganes_flat.csv (585 filas)
#  Cargado: Mallorca_flat.csv (597 filas)
#  Cargado: Osasuna_flat.csv (601 filas)
#  Cargado: Rayo_Vallecano_flat.csv (606 filas)
#  Cargado: Real_Betis_flat.csv (828 filas)
#  Cargado: Real_Madrid_flat.csv (776 filas)
#  Cargado: Real_Sociedad_flat.csv (789 filas)
#  Cargado: Real_Valladolid_flat.csv (595 filas)
#  Cargado: Sevilla_flat.csv (592 filas)
#  Cargado: Valencia_flat.csv (597 filas)
#  Cargado: Villareal_flat.csv (595 filas)
#
# ...

# %%
#  Carpeta con los CSV de jugadores 
folder_path = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados"  
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f"🔍 Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar encabezados
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

#  Cargar archivos
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")

        # Limpieza de encabezados
        df.columns = [clean_column_name(c) for c in df.columns]
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Premier_League"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Cargar en MySQL
        df.to_sql("bronze_players", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: jugadores de España cargados en 'bronze_players'")
# Out:
# 🔍 Se encontraron 20 archivos en D:\Fut_Pred\Datos_jugadores\2024-2025\Inglaterra\Combinados
#
#  Cargado: Arsenal.csv (560 filas)
#  Cargado: Aston_Villa.csv (773 filas)
#  Cargado: Bournemouth.csv (580 filas)
#  Cargado: Brentford.csv (560 filas)
#  Cargado: Brighton.csv (602 filas)
#  Cargado: Chelsea.csv (558 filas)
#  Cargado: Crystal_Palace.csv (566 filas)
#  Cargado: Everton.csv (548 filas)
#  Cargado: Fulham.csv (597 filas)
#  Cargado: Ipswich_Town.csv (596 filas)
#  Cargado: Leicester_City.csv (586 filas)
#  Cargado: Liverpool.csv (583 filas)
#  Cargado: Manchester_ City.csv (694 filas)
#  Cargado: Manchester_United.csv (579 filas)
#  Cargado: Newcastle.csv (581 filas)
#  Cargado: Nottingham_forest.csv (585 filas)
#  Cargado: Southampton.csv (598 filas)
#  Cargado: Tottenham.csv (800 filas)
#  Cargado: West_Ham.csv (590 filas)
#  Cargado: Wolves.csv (585 filas)
#
#  Proceso completado: jugadores de España cargados en 'bronze_players'

# %% [markdown]
# Italia

# %%
#  Carpeta con los CSV de jugadores 
folder_path = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados"  
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f"🔍 Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar encabezados
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

#  Cargar archivos
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")

        # Limpieza de encabezados
        df.columns = [clean_column_name(c) for c in df.columns]
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Serie_A"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Cargar en MySQL
        df.to_sql("bronze_players", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: jugadores de Italia cargados en 'bronze_players'")
# Out:
# 🔍 Se encontraron 21 archivos en D:\Fut_Pred\Datos_jugadores\2024-2025\Italia\Combinados
#
#  Cargado: AC_Milan.csv (736 filas)
#  Cargado: Atalanta.csv (763 filas)
#  Cargado: Bologna.csv (603 filas)
#  Cargado: Cagliari.csv (600 filas)
#  Cargado: Combinados.csv (2702 filas)
#  Cargado: Como.csv (605 filas)
#  Cargado: Empoli.csv (587 filas)
#  Cargado: Fiorentina.csv (785 filas)
#  Cargado: Genoa.csv (588 filas)
#  Cargado: Hellas_Verona.csv (598 filas)
#  Cargado: Inter_Milan.csv (606 filas)
#  Cargado: Juventus.csv (582 filas)
#  Cargado: Lazio.csv (782 filas)
#  Cargado: Lecce.csv (586 filas)
#  Cargado: Monza.csv (590 filas)
#  Cargado: Napoli.csv (576 filas)
#  Cargado: Parma.csv (603 filas)
#  Cargado: Roma.csv (775 filas)
#  Cargado: Torino.csv (597 filas)
#  Cargado: Udinese.csv (599 filas)
#  Cargado: Venezia.csv (605 filas)
#
#  Proceso completado: jugadores de Italia cargados en 'bronze_players'

# %%
#  Carpeta con los CSV de jugadores 
folder_path = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados"  
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f"🔍 Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar encabezados
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

#  Cargar archivos
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")

        # Limpieza de encabezados
        df.columns = [clean_column_name(c) for c in df.columns]
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Bundesliga"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Cargar en MySQL
        df.to_sql("bronze_players", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: jugadores de Alemania cargados en 'bronze_players'")
# Out:
# 🔍 Se encontraron 19 archivos en D:\Fut_Pred\Datos_jugadores\2024-2025\Alemania\Combinados
#
#  Cargado: Augsburg.csv (531 filas)
#  Cargado: Bayern_Munich.csv (738 filas)
#  Cargado: Bayer_Leverkusen.csv (510 filas)
#  Cargado: Bochum_1848.csv (528 filas)
#  Cargado: Borussia_Dortmund.csv (744 filas)
#  Cargado: Borussia_Monchengladbach.csv (539 filas)
#  Cargado: Combinados.csv (3590 filas)
#  Cargado: Frankfurt.csv (536 filas)
#  Cargado: Freiburg.csv (531 filas)
#  Cargado: Heidenheim_1846.csv (536 filas)
#  Cargado: Hoffenheim.csv (649 filas)
#  Cargado: Holstein_Kiel.csv (536 filas)
#  Cargado: Mainz_05.csv (519 filas)
#  Cargado: RB_Leipzig.csv (532 filas)
#  Cargado: St.Pauli.csv (517 filas)
#  Cargado: Stuttgart.csv (660 filas)
#  Cargado: Union_Berlin.csv (542 filas)
#  Cargado: Werder_Bremen.csv (530 filas)
#  Cargado: Wolfsburg.csv (529 filas)
#
#  Proceso completado: jugadores de Alemania cargados en 'bronze_players'

# %%
#  Carpeta con los CSV de jugadores 
folder_path = r"D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados"  
csv_files = glob(os.path.join(folder_path, "*.csv"))
print(f"🔍 Se encontraron {len(csv_files)} archivos en {folder_path}\n")

#  Función para limpiar encabezados
def clean_column_name(col):
    col = str(col).strip()
    col = re.sub(r"[^\w]+", "_", col)
    col = re.sub(r"__+", "_", col)
    col = col.strip("_")
    return col[:60]

#  Cargar archivos
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, sep=",", encoding="utf-8")

        # Limpieza de encabezados
        df.columns = [clean_column_name(c) for c in df.columns]
        df = df.loc[:, ~df.columns.duplicated()]

        # Metadatos
        df["league"] = "Ligue_1"
        df["season"] = "2024-2025"
        df["team_name"] = os.path.splitext(os.path.basename(csv_path))[0]
        df["file_source"] = os.path.basename(csv_path)

        # Cargar en MySQL
        df.to_sql("bronze_players", engine, if_exists="append", index=False, method="multi", chunksize=1000)
        print(f" Cargado: {os.path.basename(csv_path)} ({len(df)} filas)")

    except Exception as e:
        print(f" Error al cargar {os.path.basename(csv_path)} → {e}")

print("\n Proceso completado: jugadores de Francia cargados en 'bronze_players'")
# Out:
# 🔍 Se encontraron 19 archivos en D:\Fut_Pred\Datos_jugadores\2024-2025\Francia\Combinados
#
#  Cargado: Angers.csv (531 filas)
#  Cargado: As_monaco.csv (680 filas)
#  Cargado: Auxerre.csv (529 filas)
#  Cargado: Brest.csv (678 filas)
#  Cargado: Combinados.csv (2418 filas)
#  Cargado: Lens.csv (532 filas)
#  Cargado: Le_Havre.csv (521 filas)
#  Cargado: Lille.csv (681 filas)
#  Cargado: Lyon.csv (517 filas)
#  Cargado: Marseille.csv (521 filas)
#  Cargado: Montpellier.csv (512 filas)
#  Cargado: Nantes.csv (529 filas)
#  Cargado: Nice.csv (532 filas)
#  Cargado: PSG.csv (767 filas)
#  Cargado: Reims.csv (522 filas)
#  Cargado: Rennes.csv (522 filas)
#  Cargado: Saint_Etienne.csv (504 filas)
#  Cargado: Strasbourg.csv (505 filas)
#  Cargado: Toulouse.csv (514 filas)
#
#  Proceso completado: jugadores de Francia cargados en 'bronze_players'
